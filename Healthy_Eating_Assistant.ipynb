# %%
import matplotlib.pyplot as plt

# Sample food items with ingredients, and instructions for each meal
food_items = {
    "breakfast": [
        ("Oatmeal with almond milk, chia seeds, and fruit.", 350,
         ['Oats', 'Almond Milk', 'Chia Seeds', 'Fruit'], {'Oats': '1/2 cup', 'Almond Milk': '1 cup', 'Chia Seeds': '1 tbsp', 'Fruit': '1/2 cup'},
         "Instructions: Cook oats in almond milk, then top with chia seeds and fruit."),

        ("Scrambled eggs with spinach and whole-grain toast.", 400,
         ['Eggs', 'Spinach', 'Whole-grain Toast'], {'Eggs': '2', 'Spinach': '1/2 cup', 'Whole-grain Toast': '2 slices'},
         "Instructions: Scramble eggs with spinach and toast the bread."),

        ("Smoothie bowl with almond milk, gluten-free granola, and fresh fruit.", 400,
         ['Almond Milk', 'Granola', 'Fruit'], {'Almond Milk': '1 cup', 'Granola': '1/4 cup', 'Fruit': '1/2 cup'},
         "Instructions: Blend almond milk and fruit, pour into a bowl, and top with granola."),

        ("Avocado toast with poached eggs.", 380,
         ['Avocado', 'Eggs', 'Whole-grain Toast'], {'Avocado': '1/2', 'Eggs': '2', 'Whole-grain Toast': '2 slices'},
         "Instructions: Poach eggs and spread avocado on toasted bread."),

        ("Greek yogurt with mixed berries and honey.", 300,
         ['Greek Yogurt', 'Mixed Berries', 'Honey'], {'Greek Yogurt': '1 cup', 'Mixed Berries': '1/2 cup', 'Honey': '1 tbsp'},
         "Instructions: Mix Greek yogurt with berries and drizzle with honey.")
    ],
    "lunch": [
        ("Quinoa salad with chickpeas, avocado, and a lemon-tahini dressing.", 500,
         ['Quinoa', 'Chickpeas', 'Avocado', 'Lemon Tahini Dressing'], {'Quinoa': '1 cup', 'Chickpeas': '1/2 cup', 'Avocado': '1/2', 'Lemon Tahini Dressing': '2 tbsp'},
         "Instructions: Mix quinoa, chickpeas, avocado, and drizzle with lemon tahini dressing."),

        ("Grilled chicken breast with quinoa and roasted vegetables.", 600,
         ['Chicken Breast', 'Quinoa', 'Roasted Vegetables'], {'Chicken Breast': '1 piece', 'Quinoa': '1 cup', 'Roasted Vegetables': '1 cup'},
         "Instructions: Grill chicken and serve with quinoa and roasted vegetables."),

        ("Grilled chicken salad with gluten-free dressing, avocado, and mixed greens.", 550,
         ['Chicken Breast', 'Mixed Greens', 'Avocado', 'Gluten-Free Dressing'], {'Chicken Breast': '1 piece', 'Mixed Greens': '1 cup', 'Avocado': '1/2', 'Gluten-Free Dressing': '2 tbsp'},
         "Instructions: Grill chicken and mix with avocado and greens, top with dressing."),

        ("Lentil stew with brown rice and steamed broccoli.", 600,
         ['Lentils', 'Brown Rice', 'Broccoli'], {'Lentils': '1 cup', 'Brown Rice': '1/2 cup', 'Broccoli': '1 cup'},
         "Instructions: Cook lentils and brown rice. Steam broccoli and combine."),

        ("Vegan wrap with hummus, veggies, and avocado.", 450,
         ['Hummus', 'Veggies', 'Avocado', 'Wrap'], {'Hummus': '2 tbsp', 'Veggies': '1/2 cup', 'Avocado': '1/2', 'Wrap': '1'},
         "Instructions: Spread hummus on the wrap, add veggies and avocado, then roll up.")
    ],
    "snack": [
        ("Hummus with carrot and cucumber sticks.", 200,
         ['Hummus', 'Carrot', 'Cucumber'], {'Hummus': '3 tbsp', 'Carrot': '1', 'Cucumber': '1/2'},
         "Instructions: Slice carrot and cucumber, and dip in hummus."),

        ("Greek yogurt with mixed berries.", 150,
         ['Greek Yogurt', 'Mixed Berries'], {'Greek Yogurt': '1/2 cup', 'Mixed Berries': '1/4 cup'},
         "Instructions: Mix Greek yogurt with berries."),

        ("Rice cakes with peanut butter and banana slices.", 250,
         ['Rice Cakes', 'Peanut Butter', 'Banana'], {'Rice Cakes': '2', 'Peanut Butter': '1 tbsp', 'Banana': '1/2'},
         "Instructions: Spread peanut butter on rice cakes and top with banana slices."),

        ("Chia pudding with almond milk and honey.", 250,
         ['Chia Seeds', 'Almond Milk', 'Honey'], {'Chia Seeds': '2 tbsp', 'Almond Milk': '1 cup', 'Honey': '1 tbsp'},
         "Instructions: Mix chia seeds with almond milk and honey, let sit overnight."),

        ("Apple slices with almond butter.", 150,
         ['Apple', 'Almond Butter'], {'Apple': '1', 'Almond Butter': '1 tbsp'},
         "Instructions: Slice apple and dip in almond butter.")
    ],
    "dinner": [
        ("Lentil stew with brown rice and steamed broccoli.", 600,
         ['Lentils', 'Brown Rice', 'Broccoli'], {'Lentils': '1 cup', 'Brown Rice': '1/2 cup', 'Broccoli': '1 cup'},
         "Instructions: Cook lentils and brown rice. Steam broccoli and combine."),

        ("Baked salmon with sweet potato and sautéed kale.", 700,
         ['Salmon', 'Sweet Potato', 'Kale'], {'Salmon': '1 piece', 'Sweet Potato': '1 medium', 'Kale': '1 cup'},
         "Instructions: Bake salmon, roast sweet potato, and sauté kale."),

        ("Grilled chicken breast with quinoa and roasted vegetables.", 650,
         ['Chicken Breast', 'Quinoa', 'Roasted Vegetables'], {'Chicken Breast': '1 piece', 'Quinoa': '1 cup', 'Roasted Vegetables': '1 cup'},
         "Instructions: Grill chicken and serve with quinoa and roasted vegetables."),

        ("Zucchini noodles with marinara sauce and grilled shrimp.", 500,
         ['Zucchini', 'Marinara Sauce', 'Shrimp'], {'Zucchini': '1 medium', 'Marinara Sauce': '1/2 cup', 'Shrimp': '5 pieces'},
         "Instructions: Grill shrimp and serve with zucchini noodles and marinara sauce."),

        ("Baked tofu with quinoa and steamed veggies.", 550,
         ['Tofu', 'Quinoa', 'Steamed Veggies'], {'Tofu': '1 block', 'Quinoa': '1 cup', 'Steamed Veggies': '1 cup'},
         "Instructions: Bake tofu, serve with quinoa and steamed veggies.")
    ],
    "dessert": [
        ("Vegan chocolate mousse made with avocado and cacao.", 300,
         ['Avocado', 'Cacao'], {'Avocado': '1/2', 'Cacao': '1 tbsp'},
         "Instructions: Blend avocado with cacao powder and chill."),

        ("Chia pudding with almond milk and honey.", 250,
         ['Chia Seeds', 'Almond Milk', 'Honey'], {'Chia Seeds': '2 tbsp', 'Almond Milk': '1 cup', 'Honey': '1 tbsp'},
         "Instructions: Mix chia seeds with almond milk and honey, let sit overnight."),

        ("Coconut flour chocolate chip cookies.", 250,
         ['Coconut Flour', 'Chocolate Chips'], {'Coconut Flour': '1/4 cup', 'Chocolate Chips': '1 tbsp'},
         "Instructions: Mix coconut flour and chocolate chips, then bake."),

        ("Fruit salad with a sprinkle of cinnamon.", 150,
         ['Fruit', 'Cinnamon'], {'Fruit': '1 cup', 'Cinnamon': '1 tsp'},
         "Instructions: Chop fruit and sprinkle with cinnamon."),

        ("Frozen banana ice cream with almond butter.", 200,
         ['Banana', 'Almond Butter'], {'Banana': '1', 'Almond Butter': '1 tbsp'},
         "Instructions: Freeze banana, then blend with almond butter.")
    ]
}

# Function to calculate BMI
def calculate_bmi(weight, height):
    height_m = height / 100  # Convert height from cm to meters
    bmi = weight / (height_m ** 2)
    return round(bmi, 2)

# Function to suggest daily calorie intake
def suggest_calories(bmi, gender):
    standard_bmi = 22  # Standard BMI value to compare
    if bmi < standard_bmi:
        base_calories = 2400 if gender == 'male' else 2000
    elif bmi == standard_bmi:
        base_calories = 2200 if gender == 'male' else 1800
    else:
        base_calories = 2200 if gender == 'male' else 1800
    return base_calories

# Function to calculate suggested macronutrients
def suggest_macros(calories):
    carbs = round(0.55 * calories / 4)  # 55% from carbs
    protein = round(0.20 * calories / 4)  # 20% from protein
    fats = round(0.25 * calories / 9)  # 25% from fats
    return carbs, protein, fats

# Plotting the comparison pie chart
def plot_comparison_pie_chart(selected_macros, recommended_macros):
    labels = ['Carbs', 'Protein', 'Fats']

    # Selected values
    selected_sizes = [selected_macros['carbs'], selected_macros['protein'], selected_macros['fats']]

    # Recommended values
    recommended_sizes = [recommended_macros['carbs'], recommended_macros['protein'], recommended_macros['fats']]

    fig, axes = plt.subplots(1, 2, figsize=(12, 7))

    # Pie chart for selected macros
    axes[0].pie(selected_sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff','#99ff99'])
    axes[0].set_title("Selected Macros")

    # Pie chart for recommended macros
    axes[1].pie(recommended_sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=['#ffcc99','#ff6666','#99ff66'])
    axes[1].set_title("Recommended Macros")

    plt.show()

# Main logic
def main():
    weight = float(input("Enter your weight in kg: "))
    height = float(input("Enter your height in cm: "))
    gender = input("Enter your gender (male/female): ").lower()

    bmi = calculate_bmi(weight, height)
    print(f"Your BMI is: {bmi}")

    base_calories = suggest_calories(bmi, gender)
    print(f"Suggested daily caloric intake: {base_calories} calories.")

    # Allow user to choose meals
    selected_meals = {
        "breakfast": [],
        "lunch": [],
        "snack": [],
        "dinner": [],
        "dessert": []
    }

    # User selects meals
    for meal_time in selected_meals.keys():
        print(f"Select a {meal_time}:")
        for i, meal in enumerate(food_items[meal_time], 1):
            print(f"{i}. {meal[0]} ({meal[1]} calories)")
        choice = int(input(f"Enter the number of your choice for {meal_time}: "))
        selected_meals[meal_time].append(food_items[meal_time][choice-1])

    # Calculate total calories and macros for selected meals
    total_calories = 0
    total_carbs = 0
    total_protein = 0
    total_fats = 0

    print("\nYour selected meals and recipes:")
    for meal_time, meals in selected_meals.items():
        for meal in meals:
            total_calories += meal[1]
            # Placeholder values for carbs, protein, and fats (these would typically come from the recipe data)
            # Here, you can define your own logic to calculate macros based on ingredients or use predefined values
            # Assuming rough estimates for carbs, protein, and fats
            carbs, protein, fats = 0.5 * meal[1], 0.2 * meal[1], 0.3 * meal[1]  # Example distribution
            total_carbs += carbs
            total_protein += protein
            total_fats += fats
            print(f"\n{meal_time.capitalize()} - {meal[0]} ({meal[1]} calories)")
            print(f"Ingredients: {meal[2]}")
            print(f"Instructions: {meal[3]}")

    # Compare with recommended intake
    recommended_macros = {
        'carbs': 0.55 * base_calories / 4,
        'protein': 0.20 * base_calories / 4,
        'fats': 0.25 * base_calories / 9
    }

    print(f"\nTotal selected calories: {total_calories} kcal.")
    print(f"Your recommended intake: {base_calories} kcal.")

    print(f"\nTotal selected macros: Carbs: {total_carbs}g | Protein: {total_protein}g | Fats: {total_fats}g.")
    print(f"Recommended macros: Carbs: {recommended_macros['carbs']}g | Protein: {recommended_macros['protein']}g | Fats: {recommended_macros['fats']}g.")

    # Plot comparison pie chart
    selected_macros = {'carbs': total_carbs, 'protein': total_protein, 'fats': total_fats}
    plot_comparison_pie_chart(selected_macros, recommended_macros)

# Run the program
if __name__ == "__main__":
    main()
# Out:
# Enter your weight in kg: 54
# Enter your height in cm: 168
# Enter your gender (male/female): male
# Your BMI is: 19.13
# Suggested daily caloric intake: 2400 calories.
# Select a breakfast:
# 1. Oatmeal with almond milk, chia seeds, and fruit. (350 calories)
# 2. Scrambled eggs with spinach and whole-grain toast. (400 calories)
# 3. Smoothie bowl with almond milk, gluten-free granola, and fresh fruit. (400 calories)
# 4. Avocado toast with poached eggs. (380 calories)
# 5. Greek yogurt with mixed berries and honey. (300 calories)
# Enter the number of your choice for breakfast: 1
# Select a lunch:
# 1. Quinoa salad with chickpeas, avocado, and a lemon-tahini dressing. (500 calories)
# 2. Grilled chicken breast with quinoa and roasted vegetables. (600 calories)
# 3. Grilled chicken salad with gluten-free dressing, avocado, and mixed greens. (550 calories)
# 4. Lentil stew with brown rice and steamed broccoli. (600 calories)
# ...
